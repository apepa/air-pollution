# %%
import pandas as pd
import seaborn as sb

# %matplotlib inline

# %%
pm_10 = pd.read_csv('opendata/pm10--2011-2015.csv')
pm_25 = pd.read_csv('opendata/pm-2-5--2011-2015.csv')
no2 = pd.read_csv('opendata/no2-sofia-2011-2015.csv')

# %%
pm_10.head()
# Out:
#   Показател Мерна единица        Дата  средноденонощна норма      Дружба  \
# 0      PM10         ug/m3  01.01.2011                   50.0  533.884216
# 1      PM10         ug/m3  02.01.2011                   50.0  439.790344
# 2      PM10         ug/m3  03.01.2011                   50.0   57.218586
# 3      PM10         ug/m3  04.01.2011                   50.0   54.860920
# 4      PM10         ug/m3  05.01.2011                   50.0   57.547646
#
#       Павлово     Надежда  Орлов мост  Младост   Хиподрума   Копитото
# 0  550.999512  563.110291  553.935791      NaN  603.592346   5.109693
# 1  497.559631  572.875732  564.641296      NaN  579.076721  14.505280
# 2   38.543324   51.242702   57.585236      NaN   56.097775   4.246218
# 3   55.634865   43.216503   51.556568      NaN   50.372726  17.546654
# 4   32.798817   55.583721   48.208504      NaN   23.785156  19.043219

# %%
pm_10[pm_10["Копитото"] < 0] = 0 
pm_10.describe()
# Out:
#        средноденонощна норма       Дружба      Павлово      Надежда  \
# count            1825.000000  1825.000000  1826.000000  1826.000000
# mean               49.890411    46.739430    45.517292    45.428369
# std                 2.338897    43.081686    50.465144    50.217599
# min                 0.000000     0.000000     0.000000     0.000000
# 25%                50.000000    25.758348    21.612341    23.386418
# 50%                50.000000    35.540512    31.663659    32.192156
# 75%                50.000000    50.632568    46.935309    45.943150
# max                50.000000   533.884216   550.999512   572.875732
#
#         Орлов мост     Младост    Хиподрума     Копитото
# count  1736.000000   69.000000  1826.000000  1825.000000
# mean     50.640886   50.258136    45.295194    15.473619
# std      56.581017   36.384342    55.797290    13.285559
# min       0.000000    0.000000     0.000000     0.000000
# 25%      25.737673   24.661318    21.342631     5.973528
# 50%      36.585535   38.671158    30.231393    13.796797
# 75%      52.652173   77.037155    45.681221    22.954449
# max     564.641296  160.861115   606.099670   159.021637

# %%
print(pm_25['Име на български език'].describe())
print(pm_25.describe())
pm_25.head()
# Out:
# count                  1802
# unique                    1
# top       София - Хиподрума
# freq                   1802
# Name: Име на български език, dtype: object
#        средноденонощна  стойност
# count                1802.000000
# mean                   30.421876
# std                    43.005104
# min                     0.000000
# 25%                    12.006001
# 50%                    18.180001
# 75%                    30.447403
# max                   542.693542
#   Име на български език Показател Мерна единица        Дата  \
# 0     София - Хиподрума     PM2.5         ug/m3  01.01.2011
# 1     София - Хиподрума     PM2.5         ug/m3  02.01.2011
# 2     София - Хиподрума     PM2.5         ug/m3  03.01.2011
# 3     София - Хиподрума     PM2.5         ug/m3  04.01.2011
# 4     София - Хиподрума     PM2.5         ug/m3  05.01.2011
#
#    средноденонощна  стойност
# 0                 523.417114
# 1                 542.693542
# 2                  46.405773
# 3                  40.991417
# 4                  22.785963

# %%
no2.describe()
# Out:
#             Дружба      Павлово    Младост      Надежда   Орлов мост  \
# count  1802.000000  1809.000000  55.000000  1749.000000  1719.000000
# mean     23.926708    33.157001  48.838111    26.195179    42.075702
# std      15.554001    21.136918  23.058746    17.307944    19.980440
# min       3.672505     2.769727   0.221365     0.094432     7.807419
# 25%      13.612605    19.691732  30.935005    15.476769    28.337259
# 50%      19.331542    28.476774  49.501587    21.608768    39.125500
# 75%      29.264385    39.963612  64.595459    30.374975    52.704147
# max     131.966034   162.405090  95.024437   129.491760   133.071487
#
#          Хиподрума     Копитото
# count  1776.000000  1572.000000
# mean     34.222721     3.837972
# std      22.161623     3.291343
# min      -0.283923    -2.123726
# 25%      20.841449     1.498302
# 50%      29.234708     3.261966
# 75%      39.956388     5.050147
# max     181.874207    23.607035

# %%
no2[no2["Копитото"] < 0] = 0
no2[no2["Хиподрума"] < 0] = 0

# %%
no2.describe()
# Out:
#             Дружба      Павлово    Младост      Надежда   Орлов мост  \
# count  1802.000000  1809.000000  95.000000  1750.000000  1720.000000
# mean     23.062648    32.172427  27.574630    25.430852    40.885775
# std      15.378280    21.261921  29.757650    17.472468    20.643090
# min       0.000000     0.000000   0.000000     0.000000     0.000000
# 25%      13.117852    19.066647   0.000000    15.009531    27.433137
# 50%      18.760531    27.841887  21.559130    21.151948    38.273594
# 75%      28.787866    39.228897  52.838753    29.856863    51.884685
# max     131.966034   162.405090  95.024437   129.491760   133.071487
#
#          Хиподрума     Копитото
# count  1776.000000  1572.000000
# mean     33.207189     3.847856
# std      22.175484     3.272754
# min       0.000000     0.000000
# 25%      20.114511     1.497645
# 50%      28.647088     3.261141
# 75%      39.502121     5.020355
# max     181.874207    23.607035

# %%
import math
areas = ["Дружба", "Павлово", "Младост", "Надежда", "Орлов мост", "Хиподрума", "Копитото"]

# pm_10.dropna(how='any', inplace=True)
# pm_25.dropna(how='any', inplace=True)
# no2.dropna(how='any', inplace=True)

pm10_dict = pm_10.to_dict("records")
no2_dict = no2.to_dict("records")
pm25_dict = pm_25.to_dict("records")

data_aggregated = []

for d in pm10_dict:
    for area in areas:
        if math.isnan(d[area]):
            continue
        data_aggregated.append([area, d["Показател"], d[area], d["Дата"]])
        
for d in no2_dict:
    for area in areas:
        if math.isnan(d[area]) or d["Показател"] == 0:
            continue
        data_aggregated.append([area, d["Показател"], d[area], d["Дата"]])

for d in pm25_dict:
    if math.isnan(d["средноденонощна  стойност"]):
        continue
    else:
        data_aggregated.append(["Хиподрума", d["Показател"], d["средноденонощна  стойност"], d["Дата"]])

# %%
data_aggregated[12000:]
# Out:
# [['Копитото', 'NO2', 0.47532296180725103, '13.07.2011'],
#  ['Дружба', 'NO2', 12.37059020996094, '14.07.2011'],
#  ['Павлово', 'NO2', 17.65556526184082, '14.07.2011'],
#  ['Надежда', 'NO2', 27.78566551208496, '14.07.2011'],
#  ['Орлов мост', 'NO2', 56.35318374633789, '14.07.2011'],
#  ['Копитото', 'NO2', 0.4122433662414551, '14.07.2011'],
#  ['Дружба', 'NO2', 13.50833320617676, '15.07.2011'],
#  ['Павлово', 'NO2', 23.68103790283203, '15.07.2011'],
#  ['Надежда', 'NO2', 25.00334548950195, '15.07.2011'],
#  ['Орлов мост', 'NO2', 53.34601211547852, '15.07.2011'],
#  ['Копитото', 'NO2', 0.4665189981460571, '15.07.2011'],
#  ['Дружба', 'NO2', 14.8703441619873, '16.07.2011'],
#  ['Павлово', 'NO2', 17.16443061828613, '16.07.2011'],
#  ['Надежда', 'NO2', 19.83611106872559, '16.07.2011'],
#  ['Орлов мост', 'NO2', 54.00322723388672, '16.07.2011'],
#  ['Дружба', 'NO2', 10.88031578063965, '17.07.2011'],
#  ['Павлово', 'NO2', 15.08848476409912, '17.07.2011'],
#  ['Надежда', 'NO2', 17.37944412231445, '17.07.2011'],
#  ['Орлов мост', 'NO2', 40.42056274414062, '17.07.2011'],
#  ['Дружба', 'NO2', 15.87040042877197, '18.07.2011'],
#  ['Павлово', 'NO2', 19.36856269836426, '18.07.2011'],
#  ['Надежда', 'NO2', 19.72791481018066, '18.07.2011'],
#  ['Орлов мост', 'NO2', 43.801414489746094, '18.07.2011'],
#  ['Дружба', 'NO2', 14.005331039428711, '19.07.2011'],
#  ['Павлово', 'NO2', 23.42891120910645, '19.07.2011'],
#  ['Орлов мост', 'NO2', 54.67202377319336, '19.07.2011'],
#  ['Копитото', 'NO2', 0.4038726985454559, '19.07.2011'],
#  ['Дружба', 'NO2', 14.822839736938482, '20.07.2011'],
#  ['Павлово', 'NO2', 13.36820983886719, '20.07.2011'],
#  ['Орлов мост', 'NO2', 44.09115982055664, '20.07.2011'],
#  ['Дружба', 'NO2', 12.695265769958501, '21.07.2011'],
#  ['Павлово', 'NO2', 5.207962512969972, '21.07.2011'],
#  ['Орлов мост', 'NO2', 22.49491119384766, '21.07.2011'],
#  ['Хиподрума', 'NO2', 16.567924499511722, '21.07.2011'],
#  ['Дружба', 'NO2', 15.43739986419678, '22.07.2011'],
#  ['Павлово', 'NO2', 21.50331687927246, '22.07.2011'],
#  ['Орлов мост', 'NO2', 38.7378044128418, '22.07.2011'],
#  ['Хиподрума', 'NO2', 26.52544975280762, '22.07.2011'],
#  ['Копитото', 'NO2', 0.2611719369888306, '22.07.2011'],
#  ['Дружба', 'NO2', 13.55759334564209, '23.07.2011'],
#  ['Павлово', 'NO2', 25.19438552856445, '23.07.2011'],
#  ['Орлов мост', 'NO2', 43.90600967407227, '23.07.2011'],
#  ['Хиподрума', 'NO2', 25.40398406982422, '23.07.2011'],
#  ['Копитото', 'NO2', 0.3965442478656769, '23.07.2011'],
#  ['Дружба', 'NO2', 11.64423942565918, '24.07.2011'],
#  ['Павлово', 'NO2', 20.99145317077637, '24.07.2011'],
#  ['Орлов мост', 'NO2', 38.57377243041992, '24.07.2011'],
#  ['Хиподрума', 'NO2', 17.29300880432129, '24.07.2011'],
#  ['Копитото', 'NO2', 0.3352617919445038, '24.07.2011'],
#  ['Дружба', 'NO2', 16.78206253051758, '25.07.2011'],
#  ['Павлово', 'NO2', 27.1079044342041, '25.07.2011'],
#  ['Надежда', 'NO2', 20.73498153686523, '25.07.2011'],
#  ['Орлов мост', 'NO2', 47.39710235595703, '25.07.2011'],
#  ['Хиподрума', 'NO2', 28.72214698791504, '25.07.2011'],
#  ['Дружба', 'NO2', 11.41730213165283, '26.07.2011'],
#  ['Павлово', 'NO2', 25.29738426208496, '26.07.2011'],
#  ['Надежда', 'NO2', 10.15016460418701, '26.07.2011'],
#  ['Орлов мост', 'NO2', 33.28030776977539, '26.07.2011'],
#  ['Хиподрума', 'NO2', 21.80513191223145, '26.07.2011'],
#  ['Дружба', 'NO2', 11.426636695861822, '27.07.2011'],
#  ['Павлово', 'NO2', 16.6042366027832, '27.07.2011'],
#  ['Надежда', 'NO2', 6.812520503997803, '27.07.2011'],
#  ['Орлов мост', 'NO2', 27.02811050415039, '27.07.2011'],
#  ['Хиподрума', 'NO2', 19.08675575256348, '27.07.2011'],
#  ['Копитото', 'NO2', 0.3760610818862915, '27.07.2011'],
#  ['Дружба', 'NO2', 11.09256076812744, '28.07.2011'],
#  ['Павлово', 'NO2', 27.398700714111328, '28.07.2011'],
#  ['Надежда', 'NO2', 13.895772933959961, '28.07.2011'],
#  ['Орлов мост', 'NO2', 57.01889419555664, '28.07.2011'],
#  ['Хиподрума', 'NO2', 28.79809761047363, '28.07.2011'],
#  ['Копитото', 'NO2', 0.4257480502128601, '28.07.2011'],
#  ['Дружба', 'NO2', 15.91892623901367, '29.07.2011'],
#  ['Надежда', 'NO2', 16.49612998962402, '29.07.2011'],
#  ['Орлов мост', 'NO2', 48.91228866577148, '29.07.2011'],
#  ['Хиподрума', 'NO2', 28.491107940673828, '29.07.2011'],
#  ['Копитото', 'NO2', 0.4715110659599304, '29.07.2011'],
#  ['Дружба', 'NO2', 10.75809097290039, '30.07.2011'],
#  ['Павлово', 'NO2', 10.123250007629391, '30.07.2011'],
#  ['Надежда', 'NO2', 7.1630539894104, '30.07.2011'],
#  ['Орлов мост', 'NO2', 23.32144927978516, '30.07.2011'],
#  ['Хиподрума', 'NO2', 13.815138816833501, '30.07.2011'],
#  ['Копитото', 'NO2', 0.2853829562664032, '30.07.2011'],
#  ['Дружба', 'NO2', 11.23195552825928, '31.07.2011'],
#  ['Павлово', 'NO2', 15.082345962524409, '31.07.2011'],
#  ['Надежда', 'NO2', 5.5580101013183585, '31.07.2011'],
#  ['Орлов мост', 'NO2', 30.04257011413574, '31.07.2011'],
#  ['Хиподрума', 'NO2', 19.48661613464355, '31.07.2011'],
#  ['Копитото', 'NO2', 0.2643332779407501, '31.07.2011'],
#  ['Дружба', 'NO2', 14.32733917236328, '01.08.2011'],
#  ['Павлово', 'NO2', 10.77997303009033, '01.08.2011'],
#  ['Надежда', 'NO2', 8.471773147583008, '01.08.2011'],
#  ['Орлов мост', 'NO2', 23.703655242919922, '01.08.2011'],
#  ['Хиподрума', 'NO2', 13.70490264892578, '01.08.2011'],
#  ['Копитото', 'NO2', 0.2770858407020569, '01.08.2011'],
#  ['Дружба', 'NO2', 10.24711322784424, '02.08.2011'],
#  ['Павлово', 'NO2', 7.387047290802003, '02.08.2011'],
#  ['Надежда', 'NO2', 3.881609678268433, '02.08.2011'],
#  ['Орлов мост', 'NO2', 12.328226089477539, '02.08.2011'],
#  ['Хиподрума', 'NO2', 9.605046272277832, '02.08.2011'],
#  ['Копитото', 'NO2', 0.2659680247306824, '02.08.2011'],
#  ['Дружба', 'NO2', 12.32894229888916, '03.08.2011'],
#  ['Павлово', 'NO2', 15.7946720123291, '03.08.2011'],
#  ['Надежда', 'NO2', 9.946755409240724, '03.08.2011'],
#  ['Орлов мост', 'NO2', 28.36896514892578, '03.08.2011'],
#  ['Хиподрума', 'NO2', 22.55502510070801, '03.08.2011'],
#  ['Копитото', 'NO2', 0.2716014087200165, '03.08.2011'],
#  ['Дружба', 'NO2', 13.40793704986572, '04.08.2011'],
#  ['Павлово', 'NO2', 25.51799774169922, '04.08.2011'],
#  ['Надежда', 'NO2', 13.323888778686518, '04.08.2011'],
#  ['Орлов мост', 'NO2', 42.62904739379883, '04.08.2011'],
#  ['Хиподрума', 'NO2', 28.52268028259277, '04.08.2011'],
#  ['Копитото', 'NO2', 0.3127141892910004, '04.08.2011'],
#  ['Дружба', 'NO2', 9.145519256591797, '05.08.2011'],
#  ['Павлово', 'NO2', 22.11438941955566, '05.08.2011'],
#  ['Надежда', 'NO2', 11.04949378967285, '05.08.2011'],
#  ['Орлов мост', 'NO2', 41.37060928344727, '05.08.2011'],
#  ['Хиподрума', 'NO2', 20.93450355529785, '05.08.2011'],
#  ['Копитото', 'NO2', 0.3820367157459259, '05.08.2011'],
#  ['Дружба', 'NO2', 7.632834434509277, '06.08.2011'],
#  ['Павлово', 'NO2', 18.39076995849609, '06.08.2011'],
#  ['Надежда', 'NO2', 9.48516845703125, '06.08.2011'],
#  ['Орлов мост', 'NO2', 39.69668579101562, '06.08.2011'],
#  ['Хиподрума', 'NO2', 17.13913536071777, '06.08.2011'],
#  ['Копитото', 'NO2', 0.3118425011634827, '06.08.2011'],
#  ['Дружба', 'NO2', 6.965576171875, '07.08.2011'],
#  ['Павлово', 'NO2', 22.73653984069824, '07.08.2011'],
#  ['Надежда', 'NO2', 8.015266418457031, '07.08.2011'],
#  ['Орлов мост', 'NO2', 39.427101135253906, '07.08.2011'],
#  ['Хиподрума', 'NO2', 16.81258964538574, '07.08.2011'],
#  ['Копитото', 'NO2', 0.3464924693107605, '07.08.2011'],
#  ['Дружба', 'NO2', 10.82282543182373, '08.08.2011'],
#  ['Павлово', 'NO2', 31.74012184143066, '08.08.2011'],
#  ['Надежда', 'NO2', 14.46440029144287, '08.08.2011'],
#  ['Орлов мост', 'NO2', 50.08984375, '08.08.2011'],
#  ['Хиподрума', 'NO2', 28.9061107635498, '08.08.2011'],
#  ['Копитото', 'NO2', 0.4377596378326416, '08.08.2011'],
#  ['Дружба', 'NO2', 16.35257720947266, '09.08.2011'],
#  ['Павлово', 'NO2', 16.18807601928711, '09.08.2011'],
#  ['Надежда', 'NO2', 11.593541145324712, '09.08.2011'],
#  ['Орлов мост', 'NO2', 36.47696304321289, '09.08.2011'],
#  ['Хиподрума', 'NO2', 18.70749664306641, '09.08.2011'],
#  ['Копитото', 'NO2', 0.6515803337097168, '09.08.2011'],
#  ['Дружба', 'NO2', 14.776357650756841, '10.08.2011'],
#  ['Павлово', 'NO2', 12.65966129302979, '10.08.2011'],
#  ['Надежда', 'NO2', 10.88409900665283, '10.08.2011'],
#  ['Орлов мост', 'NO2', 24.15094184875488, '10.08.2011'],
#  ['Копитото', 'NO2', 0.298378974199295, '10.08.2011'],
#  ['Дружба', 'NO2', 13.609156608581538, '11.08.2011'],
#  ['Павлово', 'NO2', 9.98747444152832, '11.08.2011'],
#  ['Надежда', 'NO2', 4.6122918128967285, '11.08.2011'],
#  ['Орлов мост', 'NO2', 20.92581367492676, '11.08.2011'],
#  ['Копитото', 'NO2', 0.3169267475605011, '11.08.2011'],
#  ['Дружба', 'NO2', 16.70477676391602, '12.08.2011'],
#  ['Павлово', 'NO2', 21.43639183044434, '12.08.2011'],
#  ['Надежда', 'NO2', 10.101663589477539, '12.08.2011'],
#  ['Орлов мост', 'NO2', 41.805641174316406, '12.08.2011'],
#  ['Копитото', 'NO2', 0.4428904056549072, '12.08.2011'],
#  ['Дружба', 'NO2', 14.35007858276367, '13.08.2011'],
#  ['Павлово', 'NO2', 29.81099891662598, '13.08.2011'],
#  ['Надежда', 'NO2', 10.87068843841553, '13.08.2011'],
#  ['Орлов мост', 'NO2', 44.39804077148438, '13.08.2011'],
#  ['Хиподрума', 'NO2', 31.4340991973877, '13.08.2011'],
#  ['Копитото', 'NO2', 0.48528191447258, '13.08.2011'],
#  ['Дружба', 'NO2', 12.01207733154297, '14.08.2011'],
#  ['Павлово', 'NO2', 20.36151504516602, '14.08.2011'],
#  ['Надежда', 'NO2', 8.561675071716309, '14.08.2011'],
#  ['Хиподрума', 'NO2', 25.662212371826172, '14.08.2011'],
#  ['Копитото', 'NO2', 0.3433364033699036, '14.08.2011'],
#  ['Дружба', 'NO2', 19.46498107910156, '15.08.2011'],
#  ['Павлово', 'NO2', 28.20645141601562, '15.08.2011'],
#  ['Надежда', 'NO2', 11.998411178588869, '15.08.2011'],
#  ['Орлов мост', 'NO2', 48.93446350097656, '15.08.2011'],
#  ['Хиподрума', 'NO2', 33.00391387939453, '15.08.2011'],
#  ['Копитото', 'NO2', 0.4512779414653778, '15.08.2011'],
#  ['Дружба', 'NO2', 19.21885871887207, '16.08.2011'],
#  ['Павлово', 'NO2', 36.35309600830078, '16.08.2011'],
#  ['Надежда', 'NO2', 13.19890880584717, '16.08.2011'],
#  ['Орлов мост', 'NO2', 55.79426193237305, '16.08.2011'],
#  ['Хиподрума', 'NO2', 33.58997344970703, '16.08.2011'],
#  ['Копитото', 'NO2', 0.462401270866394, '16.08.2011'],
#  ['Дружба', 'NO2', 18.26019096374512, '17.08.2011'],
#  ['Павлово', 'NO2', 20.783447265625, '17.08.2011'],
#  ['Надежда', 'NO2', 10.89124870300293, '17.08.2011'],
#  ['Орлов мост', 'NO2', 39.95769500732422, '17.08.2011'],
#  ['Хиподрума', 'NO2', 26.12209129333496, '17.08.2011'],
#  ['Копитото', 'NO2', 0.325170636177063, '17.08.2011'],
#  ['Дружба', 'NO2', 15.513038635253912, '18.08.2011'],
#  ['Павлово', 'NO2', 32.98252487182617, '18.08.2011'],
#  ['Надежда', 'NO2', 12.22930908203125, '18.08.2011'],
#  ['Орлов мост', 'NO2', 57.07345199584961, '18.08.2011'],
#  ['Хиподрума', 'NO2', 35.88487243652344, '18.08.2011'],
#  ['Копитото', 'NO2', 0.5574322938919067, '18.08.2011'],
#  ['Дружба', 'NO2', 12.36323833465576, '19.08.2011'],
#  ['Павлово', 'NO2', 33.77260589599609, '19.08.2011'],
#  ['Надежда', 'NO2', 13.18512439727783, '19.08.2011'],
#  ['Орлов мост', 'NO2', 53.03398132324219, '19.08.2011'],
#  ['Хиподрума', 'NO2', 29.87752723693848, '19.08.2011'],
#  ['Копитото', 'NO2', 0.529316782951355, '19.08.2011'],
#  ['Дружба', 'NO2', 12.84734058380127, '20.08.2011'],
#  ['Павлово', 'NO2', 27.35300636291504, '20.08.2011'],
#  ['Надежда', 'NO2', 7.381967067718506, '20.08.2011'],
#  ['Орлов мост', 'NO2', 42.50930786132812, '20.08.2011'],
#  ['Хиподрума', 'NO2', 26.5352840423584, '20.08.2011'],
#  ['Копитото', 'NO2', 0.35305532813072205, '20.08.2011'],
#  ['Дружба', 'NO2', 13.66280937194824, '21.08.2011'],
#  ['Павлово', 'NO2', 14.81580352783203, '21.08.2011'],
#  ['Надежда', 'NO2', 4.897729873657227, '21.08.2011'],
#  ['Орлов мост', 'NO2', 44.43980407714844, '21.08.2011'],
#  ['Хиподрума', 'NO2', 15.23065853118896, '21.08.2011'],
#  ['Копитото', 'NO2', 0.3422902822494507, '21.08.2011'],
#  ['Дружба', 'NO2', 13.50569820404053, '22.08.2011'],
#  ['Павлово', 'NO2', 32.88553237915039, '22.08.2011'],
#  ['Надежда', 'NO2', 15.41543388366699, '22.08.2011'],
#  ['Орлов мост', 'NO2', 53.42289733886719, '22.08.2011'],
#  ['Хиподрума', 'NO2', 31.33305740356445, '22.08.2011'],
#  ['Копитото', 'NO2', 0.5600242018699646, '22.08.2011'],
#  ['Дружба', 'NO2', 17.31301689147949, '23.08.2011'],
#  ['Павлово', 'NO2', 36.9290657043457, '23.08.2011'],
#  ['Надежда', 'NO2', 16.04997062683105, '23.08.2011'],
#  ['Орлов мост', 'NO2', 58.45278549194336, '23.08.2011'],
#  ['Хиподрума', 'NO2', 40.74346923828125, '23.08.2011'],
#  ['Копитото', 'NO2', 0.5359482169151306, '23.08.2011'],
#  ['Дружба', 'NO2', 14.57759094238281, '24.08.2011'],
#  ['Павлово', 'NO2', 40.88191604614258, '24.08.2011'],
#  ['Надежда', 'NO2', 18.568523406982422, '24.08.2011'],
#  ['Орлов мост', 'NO2', 57.94119644165039, '24.08.2011'],
#  ['Хиподрума', 'NO2', 42.8162956237793, '24.08.2011'],
#  ['Копитото', 'NO2', 2.192968130111694, '24.08.2011'],
#  ['Дружба', 'NO2', 15.84353256225586, '25.08.2011'],
#  ['Павлово', 'NO2', 31.75653076171875, '25.08.2011'],
#  ['Надежда', 'NO2', 20.51788520812988, '25.08.2011'],
#  ['Орлов мост', 'NO2', 63.50275421142578, '25.08.2011'],
#  ['Хиподрума', 'NO2', 38.72488403320312, '25.08.2011'],
#  ['Копитото', 'NO2', 0.7717148065567017, '25.08.2011'],
#  ['Дружба', 'NO2', 10.53738975524902, '26.08.2011'],
#  ['Павлово', 'NO2', 19.8816089630127, '26.08.2011'],
#  ['Орлов мост', 'NO2', 46.75129699707031, '26.08.2011'],
#  ['Хиподрума', 'NO2', 20.33079528808594, '26.08.2011'],
#  ['Копитото', 'NO2', 0.5601747035980225, '26.08.2011'],
#  ['Дружба', 'NO2', 7.9107909202575675, '27.08.2011'],
#  ['Павлово', 'NO2', 10.9193172454834, '27.08.2011'],
#  ['Орлов мост', 'NO2', 38.11505126953125, '27.08.2011'],
#  ['Хиподрума', 'NO2', 12.276285171508789, '27.08.2011'],
#  ['Копитото', 'NO2', 0.3610498011112213, '27.08.2011'],
#  ['Дружба', 'NO2', 8.515524864196777, '28.08.2011'],
#  ['Павлово', 'NO2', 16.01235580444336, '28.08.2011'],
#  ['Орлов мост', 'NO2', 42.930809020996094, '28.08.2011'],
#  ['Хиподрума', 'NO2', 16.26861953735352, '28.08.2011'],
#  ['Копитото', 'NO2', 0.3815386295318604, '28.08.2011'],
#  ['Дружба', 'NO2', 17.24421310424805, '29.08.2011'],
#  ['Павлово', 'NO2', 34.273937225341804, '29.08.2011'],
#  ['Орлов мост', 'NO2', 57.86756896972656, '29.08.2011'],
#  ['Хиподрума', 'NO2', 34.24087142944336, '29.08.2011'],
#  ['Копитото', 'NO2', 0.6175093054771423, '29.08.2011'],
#  ['Дружба', 'NO2', 21.53271484375, '30.08.2011'],
#  ['Павлово', 'NO2', 40.29047012329102, '30.08.2011'],
#  ['Надежда', 'NO2', 15.96267890930176, '30.08.2011'],
#  ['Орлов мост', 'NO2', 64.06393432617189, '30.08.2011'],
#  ['Хиподрума', 'NO2', 48.90085983276367, '30.08.2011'],
#  ['Копитото', 'NO2', 0.5778501033782959, '30.08.2011'],
#  ['Дружба', 'NO2', 26.43492126464844, '31.08.2011'],
#  ['Павлово', 'NO2', 43.68597793579102, '31.08.2011'],
#  ['Надежда', 'NO2', 21.47628021240234, '31.08.2011'],
#  ['Орлов мост', 'NO2', 70.02489471435547, '31.08.2011'],
#  ['Хиподрума', 'NO2', 48.10210418701172, '31.08.2011'],
#  ['Копитото', 'NO2', 0.5986405611038208, '31.08.2011'],
#  ['Дружба', 'NO2', 23.17668724060059, '01.09.2011'],
#  ['Павлово', 'NO2', 37.28287124633789, '01.09.2011'],
#  ['Надежда', 'NO2', 17.58957672119141, '01.09.2011'],
#  ['Орлов мост', 'NO2', 60.66254806518555, '01.09.2011'],
#  ['Хиподрума', 'NO2', 46.03167343139648, '01.09.2011'],
#  ['Копитото', 'NO2', 0.6067074537277222, '01.09.2011'],
#  ['Дружба', 'NO2', 24.14215850830078, '02.09.2011'],
#  ['Павлово', 'NO2', 29.98661231994629, '02.09.2011'],
#  ['Надежда', 'NO2', 19.36471557617188, '02.09.2011'],
#  ['Орлов мост', 'NO2', 56.777732849121094, '02.09.2011'],
#  ['Хиподрума', 'NO2', 41.772987365722656, '02.09.2011'],
#  ['Копитото', 'NO2', 0.4749988615512848, '02.09.2011'],
#  ['Дружба', 'NO2', 20.56879425048828, '03.09.2011'],
#  ['Павлово', 'NO2', 26.07609748840332, '03.09.2011'],
#  ['Надежда', 'NO2', 17.58897590637207, '03.09.2011'],
#  ['Хиподрума', 'NO2', 29.35053634643555, '03.09.2011'],
#  ['Копитото', 'NO2', 0.4912908673286438, '03.09.2011'],
#  ['Дружба', 'NO2', 14.52308750152588, '04.09.2011'],
#  ['Павлово', 'NO2', 31.26846504211426, '04.09.2011'],
#  ['Надежда', 'NO2', 11.58945560455322, '04.09.2011'],
#  ['Хиподрума', 'NO2', 27.22629737854004, '04.09.2011'],
#  ['Дружба', 'NO2', 12.92452812194824, '05.09.2011'],
#  ['Павлово', 'NO2', 30.88088607788086, '05.09.2011'],
#  ['Надежда', 'NO2', 12.425477981567381, '05.09.2011'],
#  ['Орлов мост', 'NO2', 46.30323791503906, '05.09.2011'],
#  ['Хиподрума', 'NO2', 29.54816436767578, '05.09.2011'],
#  ['Дружба', 'NO2', 16.71592712402344, '06.09.2011'],
#  ['Павлово', 'NO2', 23.03432464599609, '06.09.2011'],
#  ['Надежда', 'NO2', 15.86362075805664, '06.09.2011'],
#  ['Орлов мост', 'NO2', 47.78662109375, '06.09.2011'],
#  ['Хиподрума', 'NO2', 24.084758758544922, '06.09.2011'],
#  ['Дружба', 'NO2', 18.66272735595703, '07.09.2011'],
#  ['Павлово', 'NO2', 20.99679374694824, '07.09.2011'],
#  ['Надежда', 'NO2', 14.080297470092768, '07.09.2011'],
#  ['Орлов мост', 'NO2', 53.72753524780273, '07.09.2011'],
#  ['Хиподрума', 'NO2', 27.63619232177734, '07.09.2011'],
#  ['Дружба', 'NO2', 19.59033584594727, '09.09.2011'],
#  ['Павлово', 'NO2', 17.02571487426758, '09.09.2011'],
#  ['Надежда', 'NO2', 9.89706802368164, '09.09.2011'],
#  ['Орлов мост', 'NO2', 39.15488815307617, '09.09.2011'],
#  ['Хиподрума', 'NO2', 22.69799995422363, '09.09.2011'],
#  ['Дружба', 'NO2', 23.73264122009277, '12.09.2011'],
#  ['Павлово', 'NO2', 47.5587272644043, '12.09.2011'],
#  ['Надежда', 'NO2', 27.00658416748047, '12.09.2011'],
#  ['Орлов мост', 'NO2', 69.00495147705078, '12.09.2011'],
#  ['Хиподрума', 'NO2', 53.39461135864258, '12.09.2011'],
#  ['Копитото', 'NO2', 4.71178674697876, '12.09.2011'],
#  ['Дружба', 'NO2', 28.797893524169922, '13.09.2011'],
#  ['Павлово', 'NO2', 46.54320526123047, '13.09.2011'],
#  ['Надежда', 'NO2', 25.78260612487793, '13.09.2011'],
#  ['Орлов мост', 'NO2', 79.57510375976562, '13.09.2011'],
#  ['Хиподрума', 'NO2', 56.71555709838867, '13.09.2011'],
#  ['Копитото', 'NO2', 1.6094323396682741, '13.09.2011'],
#  ['Дружба', 'NO2', 29.80760765075684, '14.09.2011'],
#  ['Павлово', 'NO2', 62.65594482421875, '14.09.2011'],
#  ['Надежда', 'NO2', 30.70522880554199, '14.09.2011'],
#  ['Орлов мост', 'NO2', 93.85106658935548, '14.09.2011'],
#  ['Хиподрума', 'NO2', 73.12657165527344, '14.09.2011'],
#  ['Копитото', 'NO2', 1.248183846473694, '14.09.2011'],
#  ['Дружба', 'NO2', 37.93172073364258, '15.09.2011'],
#  ['Павлово', 'NO2', 58.6729621887207, '15.09.2011'],
#  ['Надежда', 'NO2', 40.885032653808594, '15.09.2011'],
#  ['Орлов мост', 'NO2', 94.21444702148438, '15.09.2011'],
#  ['Хиподрума', 'NO2', 75.81867980957031, '15.09.2011'],
#  ['Копитото', 'NO2', 5.316231250762939, '15.09.2011'],
#  ['Дружба', 'NO2', 36.86038208007812, '16.09.2011'],
#  ['Павлово', 'NO2', 49.99749755859375, '16.09.2011'],
#  ['Надежда', 'NO2', 23.91551780700684, '16.09.2011'],
#  ['Орлов мост', 'NO2', 85.73877716064453, '16.09.2011'],
#  ['Хиподрума', 'NO2', 56.594993591308594, '16.09.2011'],
#  ['Копитото', 'NO2', 4.6974449157714835, '16.09.2011'],
#  ['Дружба', 'NO2', 23.90628433227539, '17.09.2011'],
#  ['Павлово', 'NO2', 48.72051620483398, '17.09.2011'],
#  ['Надежда', 'NO2', 27.27928924560547, '17.09.2011'],
#  ['Орлов мост', 'NO2', 81.1852798461914, '17.09.2011'],
#  ['Хиподрума', 'NO2', 55.788795471191406, '17.09.2011'],
#  ['Копитото', 'NO2', 8.584138870239258, '17.09.2011'],
#  ['Дружба', 'NO2', 15.24004364013672, '18.09.2011'],
#  ['Павлово', 'NO2', 26.86709785461426, '18.09.2011'],
#  ['Надежда', 'NO2', 12.008084297180181, '18.09.2011'],
#  ['Орлов мост', 'NO2', 52.54789352416992, '18.09.2011'],
#  ['Хиподрума', 'NO2', 19.72317504882812, '18.09.2011'],
#  ['Копитото', 'NO2', 3.2021884918212886, '18.09.2011'],
#  ['Дружба', 'NO2', 14.74905586242676, '19.09.2011'],
#  ['Павлово', 'NO2', 22.21606254577637, '19.09.2011'],
#  ['Надежда', 'NO2', 12.55355739593506, '19.09.2011'],
#  ['Орлов мост', 'NO2', 51.15403366088867, '19.09.2011'],
#  ['Хиподрума', 'NO2', 21.2838191986084, '19.09.2011'],
#  ['Копитото', 'NO2', 2.8076107501983643, '19.09.2011'],
#  ['Дружба', 'NO2', 16.13274955749512, '20.09.2011'],
#  ['Павлово', 'NO2', 22.1715087890625, '20.09.2011'],
#  ['Надежда', 'NO2', 18.17666244506836, '20.09.2011'],
#  ['Орлов мост', 'NO2', 57.56270217895508, '20.09.2011'],
#  ['Хиподрума', 'NO2', 23.76406669616699, '20.09.2011'],
#  ['Копитото', 'NO2', 2.599124908447266, '20.09.2011'],
#  ['Дружба', 'NO2', 19.6110668182373, '21.09.2011'],
#  ['Павлово', 'NO2', 42.872886657714844, '21.09.2011'],
#  ['Надежда', 'NO2', 21.05770111083984, '21.09.2011'],
#  ['Орлов мост', 'NO2', 58.09540176391602, '21.09.2011'],
#  ['Хиподрума', 'NO2', 43.8513298034668, '21.09.2011'],
#  ['Копитото', 'NO2', 5.852721214294434, '21.09.2011'],
#  ['Дружба', 'NO2', 18.52593994140625, '22.09.2011'],
#  ['Павлово', 'NO2', 28.14985466003418, '22.09.2011'],
#  ['Надежда', 'NO2', 17.87447166442871, '22.09.2011'],
#  ['Орлов мост', 'NO2', 46.21569442749023, '22.09.2011'],
#  ['Хиподрума', 'NO2', 27.95979499816895, '22.09.2011'],
#  ['Копитото', 'NO2', 3.26043438911438, '22.09.2011'],
#  ['Дружба', 'NO2', 24.47151756286621, '23.09.2011'],
#  ['Павлово', 'NO2', 26.63007926940918, '23.09.2011'],
#  ['Надежда', 'NO2', 11.41357707977295, '23.09.2011'],
#  ['Орлов мост', 'NO2', 43.68648910522461, '23.09.2011'],
#  ['Хиподрума', 'NO2', 26.83329010009766, '23.09.2011'],
#  ['Копитото', 'NO2', 3.2517504692077637, '23.09.2011'],
#  ['Дружба', 'NO2', 18.67517471313477, '24.09.2011'],
#  ['Павлово', 'NO2', 17.73052597045898, '24.09.2011'],
#  ['Надежда', 'NO2', 8.625313758850098, '24.09.2011'],
#  ['Орлов мост', 'NO2', 31.7112922668457, '24.09.2011'],
#  ['Хиподрума', 'NO2', 20.20761108398438, '24.09.2011'],
#  ['Копитото', 'NO2', 1.758979916572571, '24.09.2011'],
#  ['Дружба', 'NO2', 19.86016082763672, '25.09.2011'],
#  ['Павлово', 'NO2', 23.61318206787109, '25.09.2011'],
#  ['Надежда', 'NO2', 14.829710006713869, '25.09.2011'],
#  ['Орлов мост', 'NO2', 59.71409225463867, '25.09.2011'],
#  ['Хиподрума', 'NO2', 24.98470306396484, '25.09.2011'],
#  ['Копитото', 'NO2', 4.769307613372803, '25.09.2011'],
#  ['Дружба', 'NO2', 16.736505508422848, '26.09.2011'],
#  ['Павлово', 'NO2', 27.84188652038574, '26.09.2011'],
#  ['Надежда', 'NO2', 14.99503421783447, '26.09.2011'],
#  ['Орлов мост', 'NO2', 59.76319885253906, '26.09.2011'],
#  ['Хиподрума', 'NO2', 25.15889167785645, '26.09.2011'],
#  ['Копитото', 'NO2', 2.081820011138916, '26.09.2011'],
#  ['Дружба', 'NO2', 19.976764678955078, '27.09.2011'],
#  ['Павлово', 'NO2', 38.29935836791992, '27.09.2011'],
#  ['Надежда', 'NO2', 31.03059959411621, '27.09.2011'],
#  ['Орлов мост', 'NO2', 58.64125442504883, '27.09.2011'],
#  ['Хиподрума', 'NO2', 44.24126434326172, '27.09.2011'],
#  ['Копитото', 'NO2', 4.439864158630371, '27.09.2011'],
#  ['Дружба', 'NO2', 28.45779609680176, '28.09.2011'],
#  ['Павлово', 'NO2', 49.93514633178711, '28.09.2011'],
#  ['Надежда', 'NO2', 36.33213424682617, '28.09.2011'],
#  ['Орлов мост', 'NO2', 68.56682586669922, '28.09.2011'],
#  ['Хиподрума', 'NO2', 55.95094680786133, '28.09.2011'],
#  ['Копитото', 'NO2', 5.9398741722106925, '28.09.2011'],
#  ['Дружба', 'NO2', 33.70029830932617, '29.09.2011'],
#  ['Павлово', 'NO2', 38.71293258666992, '29.09.2011'],
#  ['Надежда', 'NO2', 24.77385711669922, '29.09.2011'],
#  ['Орлов мост', 'NO2', 50.675682067871094, '29.09.2011'],
#  ['Хиподрума', 'NO2', 38.84890747070312, '29.09.2011'],
#  ['Копитото', 'NO2', 4.552716255187988, '29.09.2011'],
#  ['Дружба', 'NO2', 29.90125274658203, '30.09.2011'],
#  ['Павлово', 'NO2', 34.351211547851555, '30.09.2011'],
#  ['Надежда', 'NO2', 25.83752632141113, '30.09.2011'],
#  ['Орлов мост', 'NO2', 57.27336502075195, '30.09.2011'],
#  ['Хиподрума', 'NO2', 45.13126754760742, '30.09.2011'],
#  ['Копитото', 'NO2', 4.328702926635741, '30.09.2011'],
#  ['Дружба', 'NO2', 32.34583282470703, '01.10.2011'],
#  ['Павлово', 'NO2', 37.35171508789062, '01.10.2011'],
#  ['Надежда', 'NO2', 22.91995811462402, '01.10.2011'],
#  ['Орлов мост', 'NO2', 51.12592697143555, '01.10.2011'],
#  ['Хиподрума', 'NO2', 41.09309005737305, '01.10.2011'],
#  ['Копитото', 'NO2', 2.47111439704895, '01.10.2011'],
#  ['Дружба', 'NO2', 27.37084579467773, '02.10.2011'],
#  ['Павлово', 'NO2', 19.21802711486816, '02.10.2011'],
#  ['Надежда', 'NO2', 26.68477058410645, '02.10.2011'],
#  ['Орлов мост', 'NO2', 58.13743209838867, '02.10.2011'],
#  ['Хиподрума', 'NO2', 26.49651336669922, '02.10.2011'],
#  ['Копитото', 'NO2', 2.277861833572388, '02.10.2011'],
#  ['Дружба', 'NO2', 35.7855224609375, '03.10.2011'],
#  ['Павлово', 'NO2', 40.91378402709961, '03.10.2011'],
#  ['Надежда', 'NO2', 27.72610664367676, '03.10.2011'],
#  ['Орлов мост', 'NO2', 64.85000610351561, '03.10.2011'],
#  ['Хиподрума', 'NO2', 47.60863494873047, '03.10.2011'],
#  ['Копитото', 'NO2', 2.431499242782593, '03.10.2011'],
#  ['Дружба', 'NO2', 38.98603057861328, '04.10.2011'],
#  ['Павлово', 'NO2', 49.26374816894531, '04.10.2011'],
#  ['Надежда', 'NO2', 37.197044372558594, '04.10.2011'],
#  ['Орлов мост', 'NO2', 75.3678207397461, '04.10.2011'],
#  ['Хиподрума', 'NO2', 58.66095352172852, '04.10.2011'],
#  ['Копитото', 'NO2', 4.761645317077637, '04.10.2011'],
#  ['Дружба', 'NO2', 43.13203048706055, '05.10.2011'],
#  ['Павлово', 'NO2', 41.327293395996094, '05.10.2011'],
#  ['Надежда', 'NO2', 37.2697639465332, '05.10.2011'],
#  ['Орлов мост', 'NO2', 78.06996154785156, '05.10.2011'],
#  ['Хиподрума', 'NO2', 54.38607788085938, '05.10.2011'],
#  ['Копитото', 'NO2', 3.3198273181915283, '05.10.2011'],
#  ['Дружба', 'NO2', 40.869773864746094, '06.10.2011'],
#  ['Павлово', 'NO2', 63.294822692871094, '06.10.2011'],
#  ['Надежда', 'NO2', 53.996421813964844, '06.10.2011'],
#  ['Орлов мост', 'NO2', 100.32764434814449, '06.10.2011'],
#  ['Хиподрума', 'NO2', 77.54000091552734, '06.10.2011'],
#  ['Копитото', 'NO2', 6.8003363609313965, '06.10.2011'],
#  ['Дружба', 'NO2', 40.01865768432617, '07.10.2011'],
#  ['Павлово', 'NO2', 49.520713806152344, '07.10.2011'],
#  ['Надежда', 'NO2', 32.19768905639648, '07.10.2011'],
#  ['Орлов мост', 'NO2', 73.86354064941406, '07.10.2011'],
#  ['Хиподрума', 'NO2', 52.17847061157227, '07.10.2011'],
#  ['Копитото', 'NO2', 2.446902751922607, '07.10.2011'],
#  ['Дружба', 'NO2', 25.80843734741211, '08.10.2011'],
#  ['Павлово', 'NO2', 17.264032363891598, '08.10.2011'],
#  ['Надежда', 'NO2', 18.30358505249023, '08.10.2011'],
#  ['Орлов мост', 'NO2', 38.26987838745117, '08.10.2011'],
#  ['Хиподрума', 'NO2', 20.81235122680664, '08.10.2011'],
#  ['Копитото', 'NO2', 2.4706673622131348, '08.10.2011'],
#  ['Дружба', 'NO2', 20.11556816101074, '09.10.2011'],
#  ['Павлово', 'NO2', 10.55016708374023, '09.10.2011'],
#  ['Надежда', 'NO2', 9.88377285003662, '09.10.2011'],
#  ['Орлов мост', 'NO2', 14.01815414428711, '09.10.2011'],
#  ['Хиподрума', 'NO2', 11.18830108642578, '09.10.2011'],
#  ['Копитото', 'NO2', 1.287490844726562, '09.10.2011'],
#  ['Дружба', 'NO2', 26.7827262878418, '10.10.2011'],
#  ['Павлово', 'NO2', 33.333938598632805, '10.10.2011'],
#  ['Надежда', 'NO2', 26.7014274597168, '10.10.2011'],
#  ['Орлов мост', 'NO2', 39.17011642456055, '10.10.2011'],
#  ['Хиподрума', 'NO2', 34.41168975830078, '10.10.2011'],
#  ['Копитото', 'NO2', 2.728272914886475, '10.10.2011'],
#  ['Дружба', 'NO2', 27.77153968811035, '11.10.2011'],
#  ['Павлово', 'NO2', 22.51008224487305, '11.10.2011'],
#  ['Надежда', 'NO2', 15.98848438262939, '11.10.2011'],
#  ['Орлов мост', 'NO2', 30.86622428894043, '11.10.2011'],
#  ['Хиподрума', 'NO2', 26.44530868530273, '11.10.2011'],
#  ['Копитото', 'NO2', 1.6628451347351068, '11.10.2011'],
#  ['Дружба', 'NO2', 25.108013153076172, '12.10.2011'],
#  ['Павлово', 'NO2', 16.317741394042972, '12.10.2011'],
#  ['Надежда', 'NO2', 14.21886539459229, '12.10.2011'],
#  ['Орлов мост', 'NO2', 22.51390838623047, '12.10.2011'],
#  ['Хиподрума', 'NO2', 19.71159172058105, '12.10.2011'],
#  ['Копитото', 'NO2', 2.100275039672852, '12.10.2011'],
#  ['Дружба', 'NO2', 29.04502105712891, '13.10.2011'],
#  ['Павлово', 'NO2', 30.3523063659668, '13.10.2011'],
#  ['Орлов мост', 'NO2', 39.62796020507812, '13.10.2011'],
#  ['Хиподрума', 'NO2', 30.91289901733398, '13.10.2011'],
#  ['Дружба', 'NO2', 22.36784934997559, '14.10.2011'],
#  ['Павлово', 'NO2', 28.38010215759277, '14.10.2011'],
#  ['Надежда', 'NO2', 19.32290649414062, '14.10.2011'],
#  ['Орлов мост', 'NO2', 34.17896270751953, '14.10.2011'],
#  ['Хиподрума', 'NO2', 27.79540824890137, '14.10.2011'],
#  ['Дружба', 'NO2', 23.40168190002441, '15.10.2011'],
#  ['Павлово', 'NO2', 17.97554969787598, '15.10.2011'],
#  ['Надежда', 'NO2', 15.438377380371088, '15.10.2011'],
#  ['Орлов мост', 'NO2', 28.52759552001953, '15.10.2011'],
#  ['Хиподрума', 'NO2', 17.88311004638672, '15.10.2011'],
#  ['Копитото', 'NO2', 5.522985458374023, '15.10.2011'],
#  ['Дружба', 'NO2', 17.09306716918945, '16.10.2011'],
#  ['Павлово', 'NO2', 21.2952823638916, '16.10.2011'],
#  ['Надежда', 'NO2', 16.11983108520508, '16.10.2011'],
#  ['Орлов мост', 'NO2', 25.284709930419922, '16.10.2011'],
#  ['Хиподрума', 'NO2', 17.74970817565918, '16.10.2011'],
#  ['Копитото', 'NO2', 2.032830476760864, '16.10.2011'],
#  ['Дружба', 'NO2', 19.75541877746582, '17.10.2011'],
#  ['Павлово', 'NO2', 29.62067794799805, '17.10.2011'],
#  ['Надежда', 'NO2', 21.12146759033203, '17.10.2011'],
#  ['Орлов мост', 'NO2', 34.02379608154297, '17.10.2011'],
#  ['Хиподрума', 'NO2', 27.0937671661377, '17.10.2011'],
#  ['Копитото', 'NO2', 4.2090673446655265, '17.10.2011'],
#  ['Дружба', 'NO2', 29.25872039794922, '18.10.2011'],
#  ['Павлово', 'NO2', 28.49077224731445, '18.10.2011'],
#  ['Надежда', 'NO2', 16.17253494262695, '18.10.2011'],
#  ['Орлов мост', 'NO2', 29.54505920410156, '18.10.2011'],
#  ['Хиподрума', 'NO2', 27.1238842010498, '18.10.2011'],
#  ['Копитото', 'NO2', 1.6742054224014282, '18.10.2011'],
#  ['Павлово', 'NO2', 64.02001953125, '19.10.2011'],
#  ['Надежда', 'NO2', 49.268310546875, '19.10.2011'],
#  ['Орлов мост', 'NO2', 76.75455474853516, '19.10.2011'],
#  ['Хиподрума', 'NO2', 70.30721282958984, '19.10.2011'],
#  ['Копитото', 'NO2', 0.7247642874717712, '19.10.2011'],
#  ['Павлово', 'NO2', 83.49462127685547, '20.10.2011'],
#  ['Надежда', 'NO2', 64.3364028930664, '20.10.2011'],
#  ['Орлов мост', 'NO2', 76.1507797241211, '20.10.2011'],
#  ['Хиподрума', 'NO2', 86.71077728271484, '20.10.2011'],
#  ['Копитото', 'NO2', 6.526101589202881, '20.10.2011'],
#  ['Дружба', 'NO2', 56.49817657470703, '21.10.2011'],
#  ['Павлово', 'NO2', 79.08560180664062, '21.10.2011'],
#  ['Надежда', 'NO2', 47.96245193481445, '21.10.2011'],
#  ['Орлов мост', 'NO2', 78.25931549072266, '21.10.2011'],
#  ['Хиподрума', 'NO2', 88.01671600341797, '21.10.2011'],
#  ['Копитото', 'NO2', 8.394058227539062, '21.10.2011'],
#  ['Дружба', 'NO2', 27.514240264892578, '22.10.2011'],
#  ['Павлово', 'NO2', 32.96960067749023, '22.10.2011'],
#  ['Надежда', 'NO2', 22.35630226135254, '22.10.2011'],
#  ['Орлов мост', 'NO2', 45.40093612670898, '22.10.2011'],
#  ['Хиподрума', 'NO2', 31.024555206298828, '22.10.2011'],
#  ['Копитото', 'NO2', 4.881823539733887, '22.10.2011'],
#  ['Дружба', 'NO2', 14.503335952758789, '23.10.2011'],
#  ['Павлово', 'NO2', 21.2807674407959, '23.10.2011'],
#  ['Надежда', 'NO2', 19.36811828613281, '23.10.2011'],
#  ['Орлов мост', 'NO2', 44.07793426513672, '23.10.2011'],
#  ['Хиподрума', 'NO2', 19.45669364929199, '23.10.2011'],
#  ['Копитото', 'NO2', 2.967854261398315, '23.10.2011'],
#  ['Дружба', 'NO2', 16.39578247070312, '24.10.2011'],
#  ['Павлово', 'NO2', 27.19580841064453, '24.10.2011'],
#  ['Надежда', 'NO2', 24.67071723937988, '24.10.2011'],
#  ['Орлов мост', 'NO2', 47.023170471191406, '24.10.2011'],
#  ['Хиподрума', 'NO2', 29.45739555358887, '24.10.2011'],
#  ['Копитото', 'NO2', 2.698302507400513, '24.10.2011'],
#  ['Дружба', 'NO2', 21.36454200744629, '25.10.2011'],
#  ['Павлово', 'NO2', 34.200881958007805, '25.10.2011'],
#  ['Надежда', 'NO2', 26.98036956787109, '25.10.2011'],
#  ['Орлов мост', 'NO2', 46.743019104003906, '25.10.2011'],
#  ['Хиподрума', 'NO2', 37.66950607299805, '25.10.2011'],
#  ['Копитото', 'NO2', 3.120042085647583, '25.10.2011'],
#  ['Дружба', 'NO2', 19.9971752166748, '26.10.2011'],
#  ['Павлово', 'NO2', 29.02087783813477, '26.10.2011'],
#  ['Надежда', 'NO2', 27.21705055236816, '26.10.2011'],
#  ['Орлов мост', 'NO2', 43.38880920410156, '26.10.2011'],
#  ['Хиподрума', 'NO2', 31.68778800964355, '26.10.2011'],
#  ['Копитото', 'NO2', 2.616027355194092, '26.10.2011'],
#  ['Дружба', 'NO2', 18.78166198730469, '27.10.2011'],
#  ['Павлово', 'NO2', 21.2906665802002, '27.10.2011'],
#  ['Надежда', 'NO2', 22.3548698425293, '27.10.2011'],
#  ['Орлов мост', 'NO2', 39.1254997253418, '27.10.2011'],
#  ['Хиподрума', 'NO2', 23.56968116760254, '27.10.2011'],
#  ['Копитото', 'NO2', 2.32079291343689, '27.10.2011'],
#  ['Дружба', 'NO2', 23.92374420166016, '29.10.2011'],
#  ['Павлово', 'NO2', 44.858680725097656, '29.10.2011'],
#  ['Надежда', 'NO2', 29.16908836364746, '29.10.2011'],
#  ['Орлов мост', 'NO2', 46.59841918945312, '29.10.2011'],
#  ['Хиподрума', 'NO2', 41.95218276977539, '29.10.2011'],
#  ['Копитото', 'NO2', 1.8786141872406008, '29.10.2011'],
#  ['Дружба', 'NO2', 33.42495727539062, '30.10.2011'],
#  ['Павлово', 'NO2', 52.15190505981445, '30.10.2011'],
#  ['Надежда', 'NO2', 37.15175247192383, '30.10.2011'],
#  ['Орлов мост', 'NO2', 52.24103164672852, '30.10.2011'],
#  ['Хиподрума', 'NO2', 56.29704284667969, '30.10.2011'],
#  ['Копитото', 'NO2', 4.349281787872314, '30.10.2011'],
#  ['Дружба', 'NO2', 44.93390274047852, '31.10.2011'],
#  ['Павлово', 'NO2', 74.16395568847656, '31.10.2011'],
#  ['Надежда', 'NO2', 61.13039779663086, '31.10.2011'],
#  ['Орлов мост', 'NO2', 72.7962417602539, '31.10.2011'],
#  ['Хиподрума', 'NO2', 82.62654876708984, '31.10.2011'],
#  ['Копитото', 'NO2', 3.84864354133606, '31.10.2011'],
#  ['Дружба', 'NO2', 65.93263244628906, '01.11.2011'],
#  ['Павлово', 'NO2', 80.74082946777344, '01.11.2011'],
#  ['Надежда', 'NO2', 60.56946563720703, '01.11.2011'],
#  ['Орлов мост', 'NO2', 86.36725616455078, '01.11.2011'],
#  ['Хиподрума', 'NO2', 97.16322326660156, '01.11.2011'],
#  ['Копитото', 'NO2', 6.530391216278076, '01.11.2011'],
#  ['Дружба', 'NO2', 50.9372673034668, '02.11.2011'],
#  ['Павлово', 'NO2', 69.75089263916016, '02.11.2011'],
#  ['Надежда', 'NO2', 52.39253616333008, '02.11.2011'],
#  ['Орлов мост', 'NO2', 70.30640411376953, '02.11.2011'],
#  ['Хиподрума', 'NO2', 70.31673431396484, '02.11.2011'],
#  ['Копитото', 'NO2', 7.064494609832764, '02.11.2011'],
#  ['Дружба', 'NO2', 56.253517150878906, '03.11.2011'],
#  ['Павлово', 'NO2', 71.07139587402344, '03.11.2011'],
#  ['Надежда', 'NO2', 48.07623291015625, '03.11.2011'],
#  ['Орлов мост', 'NO2', 71.57520294189453, '03.11.2011'],
#  ['Хиподрума', 'NO2', 78.82267761230469, '03.11.2011'],
#  ['Копитото', 'NO2', 7.793957710266112, '03.11.2011'],
#  ['Дружба', 'NO2', 47.30366516113281, '04.11.2011'],
#  ['Павлово', 'NO2', 69.40845489501953, '04.11.2011'],
#  ['Надежда', 'NO2', 49.41048812866211, '04.11.2011'],
#  ['Орлов мост', 'NO2', 65.71360778808594, '04.11.2011'],
#  ['Хиподрума', 'NO2', 74.73217010498047, '04.11.2011'],
#  ['Копитото', 'NO2', 5.41204309463501, '04.11.2011'],
#  ['Дружба', 'NO2', 54.36135864257812, '05.11.2011'],
#  ['Павлово', 'NO2', 77.07234954833984, '05.11.2011'],
#  ['Надежда', 'NO2', 60.94805145263672, '05.11.2011'],
#  ['Орлов мост', 'NO2', 73.4828872680664, '05.11.2011'],
#  ['Хиподрума', 'NO2', 84.2413101196289, '05.11.2011'],
#  ['Копитото', 'NO2', 0.9199352264404296, '05.11.2011'],
#  ['Дружба', 'NO2', 34.461780548095696, '06.11.2011'],
#  ['Павлово', 'NO2', 39.3829231262207, '06.11.2011'],
#  ['Надежда', 'NO2', 36.24655532836914, '06.11.2011'],
#  ['Орлов мост', 'NO2', 51.88051223754883, '06.11.2011'],
#  ['Хиподрума', 'NO2', 43.656578063964844, '06.11.2011'],
#  ['Копитото', 'NO2', 2.836455583572388, '06.11.2011'],
#  ['Дружба', 'NO2', 20.05919456481934, '07.11.2011'],
#  ['Павлово', 'NO2', 20.89541244506836, '07.11.2011'],
#  ['Надежда', 'NO2', 22.08325576782227, '07.11.2011'],
#  ['Орлов мост', 'NO2', 42.77045059204102, '07.11.2011'],
#  ['Хиподрума', 'NO2', 26.15873908996582, '07.11.2011'],
#  ['Копитото', 'NO2', 1.38212788105011, '07.11.2011'],
#  ['Дружба', 'NO2', 29.63821792602539, '08.11.2011'],
#  ['Павлово', 'NO2', 41.037742614746094, '08.11.2011'],
#  ['Надежда', 'NO2', 34.62557601928711, '08.11.2011'],
#  ['Орлов мост', 'NO2', 48.62247848510742, '08.11.2011'],
#  ['Хиподрума', 'NO2', 46.04151153564453, '08.11.2011'],
#  ['Копитото', 'NO2', 2.482123613357544, '08.11.2011'],
#  ['Дружба', 'NO2', 43.40485000610352, '10.11.2011'],
#  ['Павлово', 'NO2', 43.793251037597656, '10.11.2011'],
#  ['Надежда', 'NO2', 31.6230297088623, '10.11.2011'],
#  ['Орлов мост', 'NO2', 54.36299514770508, '10.11.2011'],
#  ['Хиподрума', 'NO2', 48.28269958496094, '10.11.2011'],
#  ['Копитото', 'NO2', 5.432897090911865, '10.11.2011'],
#  ['Дружба', 'NO2', 21.9647388458252, '11.11.2011'],
#  ['Павлово', 'NO2', 25.37267684936523, '11.11.2011'],
#  ['Надежда', 'NO2', 40.06645584106445, '11.11.2011'],
#  ['Орлов мост', 'NO2', 37.15256118774414, '11.11.2011'],
#  ['Хиподрума', 'NO2', 26.73208427429199, '11.11.2011'],
#  ['Копитото', 'NO2', 2.785100936889648, '11.11.2011'],
#  ['Дружба', 'NO2', 22.63015365600586, '12.11.2011'],
#  ['Павлово', 'NO2', 21.31745719909668, '12.11.2011'],
#  ['Надежда', 'NO2', 60.94805145263672, '12.11.2011'],
#  ['Орлов мост', 'NO2', 37.89103317260742, '12.11.2011'],
#  ['Хиподрума', 'NO2', 23.30111694335938, '12.11.2011'],
#  ['Копитото', 'NO2', 3.8518140316009517, '12.11.2011'],
#  ['Дружба', 'NO2', 29.96383666992188, '13.11.2011'],
#  ['Павлово', 'NO2', 36.40026092529297, '13.11.2011'],
#  ['Надежда', 'NO2', 36.24655532836914, '13.11.2011'],
#  ['Орлов мост', 'NO2', 38.9243278503418, '13.11.2011'],
#  ['Хиподрума', 'NO2', 27.52852058410645, '13.11.2011'],
#  ['Копитото', 'NO2', 7.066142559051514, '13.11.2011'],
#  ['Дружба', 'NO2', 38.80119323730469, '14.11.2011'],
#  ['Павлово', 'NO2', 38.25383377075195, '14.11.2011'],
#  ['Надежда', 'NO2', 28.56183242797852, '14.11.2011'],
#  ['Орлов мост', 'NO2', 45.27963638305664, '14.11.2011'],
#  ['Хиподрума', 'NO2', 39.26625442504883, '14.11.2011'],
#  ['Копитото', 'NO2', 12.66105365753174, '14.11.2011'],
#  ['Дружба', 'NO2', 50.31675720214844, '15.11.2011'],
#  ['Павлово', 'NO2', 66.7371597290039, '15.11.2011'],
#  ['Надежда', 'NO2', 48.80755996704102, '15.11.2011'],
#  ['Орлов мост', 'NO2', 72.75727844238281, '15.11.2011'],
#  ['Хиподрума', 'NO2', 74.64633178710938, '15.11.2011'],
#  ['Копитото', 'NO2', 1.200281500816345, '15.11.2011'],
#  ['Дружба', 'NO2', 79.14590454101562, '16.11.2011'],
#  ['Павлово', 'NO2', 62.48496627807617, '16.11.2011'],
#  ['Надежда', 'NO2', 46.30511474609375, '16.11.2011'],
#  ['Орлов мост', 'NO2', 74.4780044555664, '16.11.2011'],
#  ['Хиподрума', 'NO2', 71.91764068603516, '16.11.2011'],
#  ['Копитото', 'NO2', 0.7931032776832581, '16.11.2011'],
#  ['Дружба', 'NO2', 66.13037109375, '17.11.2011'],
#  ['Павлово', 'NO2', 75.43606567382812, '17.11.2011'],
#  ['Надежда', 'NO2', 56.11691665649414, '17.11.2011'],
#  ['Орлов мост', 'NO2', 79.16085052490234, '17.11.2011'],
#  ['Хиподрума', 'NO2', 84.7962875366211, '17.11.2011'],
#  ['Копитото', 'NO2', 8.559887886047362, '17.11.2011'],
#  ['Дружба', 'NO2', 84.16036987304688, '18.11.2011'],
#  ['Павлово', 'NO2', 69.46271514892578, '18.11.2011'],
#  ['Надежда', 'NO2', 49.42593765258789, '18.11.2011'],
#  ['Орлов мост', 'NO2', 79.21772003173828, '18.11.2011'],
#  ['Хиподрума', 'NO2', 81.34463500976562, '18.11.2011'],
#  ['Копитото', 'NO2', 3.4012808799743652, '18.11.2011'],
#  ['Дружба', 'NO2', 69.51931762695311, '20.11.2011'],
#  ['Павлово', 'NO2', 86.4383773803711, '20.11.2011'],
#  ['Надежда', 'NO2', 70.26598358154297, '20.11.2011'],
#  ['Орлов мост', 'NO2', 91.33904266357422, '20.11.2011'],
#  ['Хиподрума', 'NO2', 103.8973617553711, '20.11.2011'],
#  ['Копитото', 'NO2', 2.646001577377319, '20.11.2011'],
#  ['Дружба', 'NO2', 95.33917236328124, '21.11.2011'],
#  ['Павлово', 'NO2', 99.98225402832031, '21.11.2011'],
#  ['Надежда', 'NO2', 83.01238250732422, '21.11.2011'],
#  ['Орлов мост', 'NO2', 105.87987518310551, '21.11.2011'],
#  ['Хиподрума', 'NO2', 124.6002044677734, '21.11.2011'],
#  ['Копитото', 'NO2', 5.594514846801758, '21.11.2011'],
#  ['Дружба', 'NO2', 104.3700942993164, '22.11.2011'],
#  ['Павлово', 'NO2', 112.6621932983398, '22.11.2011'],
#  ['Надежда', 'NO2', 96.62143707275392, '22.11.2011'],
#  ['Орлов мост', 'NO2', 120.39178466796879, '22.11.2011'],
#  ['Хиподрума', 'NO2', 148.4979705810547, '22.11.2011'],
#  ['Копитото', 'NO2', 3.303819417953491, '22.11.2011'],
#  ['Дружба', 'NO2', 60.79811477661133, '23.11.2011'],
#  ['Павлово', 'NO2', 94.20246124267578, '23.11.2011'],
#  ['Надежда', 'NO2', 60.438865661621094, '23.11.2011'],
#  ['Орлов мост', 'NO2', 82.7103042602539, '23.11.2011'],
#  ['Хиподрума', 'NO2', 98.36273956298828, '23.11.2011'],
#  ['Копитото', 'NO2', 19.81143188476562, '23.11.2011'],
#  ['Дружба', 'NO2', 28.52448463439941, '24.11.2011'],
#  ['Павлово', 'NO2', 39.40978240966797, '24.11.2011'],
#  ['Надежда', 'NO2', 29.33407402038574, '24.11.2011'],
#  ['Орлов мост', 'NO2', 41.82715606689453, '24.11.2011'],
#  ['Хиподрума', 'NO2', 32.60835647583008, '24.11.2011'],
#  ['Копитото', 'NO2', 9.300042152404783, '24.11.2011'],
#  ['Дружба', 'NO2', 38.35781860351562, '25.11.2011'],
#  ['Павлово', 'NO2', 49.66170883178711, '25.11.2011'],
#  ['Надежда', 'NO2', 43.78158950805664, '25.11.2011'],
#  ['Орлов мост', 'NO2', 61.09860610961914, '25.11.2011'],
#  ['Хиподрума', 'NO2', 51.05004501342773, '25.11.2011'],
#  ['Копитото', 'NO2', 9.342395782470703, '25.11.2011'],
#  ['Дружба', 'NO2', 40.845436096191406, '26.11.2011'],
#  ['Павлово', 'NO2', 23.768230438232422, '26.11.2011'],
#  ['Надежда', 'NO2', 21.56664848327637, '26.11.2011'],
#  ['Орлов мост', 'NO2', 31.45677757263184, '26.11.2011'],
#  ['Хиподрума', 'NO2', 18.76323509216309, '26.11.2011'],
#  ['Копитото', 'NO2', 1.649479269981384, '26.11.2011'],
#  ['Дружба', 'NO2', 49.99129867553711, '29.11.2011'],
#  ['Павлово', 'NO2', 64.60174560546875, '29.11.2011'],
#  ['Надежда', 'NO2', 46.8009033203125, '29.11.2011'],
#  ['Орлов мост', 'NO2', 67.35694885253906, '29.11.2011'],
#  ['Хиподрума', 'NO2', 63.06116104125977, '29.11.2011'],
#  ['Копитото', 'NO2', 2.55568265914917, '29.11.2011'],
#  ['Дружба', 'NO2', 101.63150024414058, '30.11.2011'],
#  ['Павлово', 'NO2', 114.192626953125, '30.11.2011'],
#  ['Надежда', 'NO2', 89.27879333496094, '30.11.2011'],
#  ['Орлов мост', 'NO2', 114.05298614501949, '30.11.2011'],
#  ['Хиподрума', 'NO2', 166.2034759521484, '30.11.2011'],
#  ['Копитото', 'NO2', 1.820761799812317, '30.11.2011'],
#  ['Дружба', 'NO2', 94.67618560791016, '02.12.2011'],
#  ['Павлово', 'NO2', 111.89380645751949, '02.12.2011'],
#  ['Надежда', 'NO2', 74.97401428222656, '02.12.2011'],
#  ['Орлов мост', 'NO2', 117.23387908935551, '02.12.2011'],
#  ['Хиподрума', 'NO2', 141.8241577148438, '02.12.2011'],
#  ['Копитото', 'NO2', 4.095308780670166, '02.12.2011'],
#  ['Дружба', 'NO2', 105.6466827392578, '03.12.2011'],
#  ['Павлово', 'NO2', 119.6978759765625, '03.12.2011'],
#  ['Надежда', 'NO2', 87.91889190673828, '03.12.2011'],
#  ['Орлов мост', 'NO2', 114.42022705078121, '03.12.2011'],
#  ['Хиподрума', 'NO2', 144.5045318603516, '03.12.2011'],
#  ['Копитото', 'NO2', 1.7472662925720208, '03.12.2011'],
#  ['Дружба', 'NO2', 34.94830322265625, '06.12.2011'],
#  ['Павлово', 'NO2', 31.14053916931152, '06.12.2011'],
#  ['Надежда', 'NO2', 16.29401016235352, '06.12.2011'],
#  ['Орлов мост', 'NO2', 30.06570434570312, '06.12.2011'],
#  ['Хиподрума', 'NO2', 23.63797760009766, '06.12.2011'],
#  ['Копитото', 'NO2', 0.5187625885009766, '06.12.2011'],
#  ['Дружба', 'NO2', 41.46709823608398, '16.12.2011'],
#  ['Павлово', 'NO2', 40.03900527954102, '16.12.2011'],
#  ['Надежда', 'NO2', 31.415283203125, '16.12.2011'],
#  ['Орлов мост', 'NO2', 51.53280258178711, '16.12.2011'],
#  ['Хиподрума', 'NO2', 45.81934356689453, '16.12.2011'],
#  ['Дружба', 'NO2', 30.46895408630371, '17.12.2011'],
#  ['Павлово', 'NO2', 17.7359447479248, '17.12.2011'],
#  ['Надежда', 'NO2', 26.76492881774902, '17.12.2011'],
#  ['Орлов мост', 'NO2', 40.79864120483398, '17.12.2011'],
#  ['Хиподрума', 'NO2', 16.09547805786133, '17.12.2011'],
#  ['Копитото', 'NO2', 0.6143706440925598, '17.12.2011'],
#  ['Дружба', 'NO2', 25.16426277160645, '18.12.2011'],
#  ['Павлово', 'NO2', 26.54693794250488, '18.12.2011'],
#  ['Надежда', 'NO2', 20.13720893859863, '18.12.2011'],
#  ['Орлов мост', 'NO2', 34.649856567382805, '18.12.2011'],
#  ['Хиподрума', 'NO2', 28.72895622253418, '18.12.2011'],
#  ['Копитото', 'NO2', 1.061996936798096, '18.12.2011'],
#  ['Дружба', 'NO2', 28.572002410888672, '19.12.2011'],
#  ['Павлово', 'NO2', 39.94318008422852, '19.12.2011'],
#  ['Надежда', 'NO2', 25.73456954956055, '19.12.2011'],
#  ['Орлов мост', 'NO2', 46.251930236816406, '19.12.2011'],
#  ['Хиподрума', 'NO2', 36.83675003051758, '19.12.2011'],
#  ['Копитото', 'NO2', 3.108893394470215, '19.12.2011'],
#  ['Дружба', 'NO2', 32.833847045898445, '20.12.2011'],
#  ['Павлово', 'NO2', 35.62895965576172, '20.12.2011'],
#  ['Надежда', 'NO2', 23.74583625793457, '20.12.2011'],
#  ['Орлов мост', 'NO2', 34.79711151123047, '20.12.2011'],
#  ['Хиподрума', 'NO2', 31.37072944641113, '20.12.2011'],
#  ['Копитото', 'NO2', 5.210379600524902, '20.12.2011'],
#  ['Дружба', 'NO2', 28.66068840026855, '21.12.2011'],
#  ['Павлово', 'NO2', 21.51677131652832, '21.12.2011'],
#  ['Надежда', 'NO2', 17.592168807983402, '21.12.2011'],
#  ['Орлов мост', 'NO2', 23.660137176513672, '21.12.2011'],
#  ['Хиподрума', 'NO2', 15.262510299682619, '21.12.2011'],
#  ['Копитото', 'NO2', 1.484357714653015, '21.12.2011'],
#  ['Дружба', 'NO2', 36.01046752929688, '22.12.2011'],
#  ['Павлово', 'NO2', 43.35853958129883, '22.12.2011'],
#  ['Надежда', 'NO2', 26.75882911682129, '22.12.2011'],
#  ['Орлов мост', 'NO2', 46.23627853393555, '22.12.2011'],
#  ['Хиподрума', 'NO2', 42.19171524047852, '22.12.2011'],
#  ['Копитото', 'NO2', 5.445223331451416, '22.12.2011'],
#  ['Дружба', 'NO2', 30.94721221923828, '23.12.2011'],
#  ['Павлово', 'NO2', 35.67260360717773, '23.12.2011'],
#  ['Надежда', 'NO2', 26.81068992614746, '23.12.2011'],
#  ['Орлов мост', 'NO2', 35.82032775878906, '23.12.2011'],
#  ['Хиподрума', 'NO2', 38.15348815917969, '23.12.2011'],
#  ['Копитото', 'NO2', 9.015939712524414, '23.12.2011'],
#  ['Дружба', 'NO2', 32.417041778564446, '24.12.2011'],
#  ['Павлово', 'NO2', 29.1003589630127, '24.12.2011'],
#  ['Надежда', 'NO2', 24.4481029510498, '24.12.2011'],
#  ['Орлов мост', 'NO2', 36.04928970336914, '24.12.2011'],
#  ['Хиподрума', 'NO2', 37.09976196289062, '24.12.2011'],
#  ['Копитото', 'NO2', 1.72990620136261, '24.12.2011'],
#  ['Дружба', 'NO2', 37.35735321044922, '25.12.2011'],
#  ['Павлово', 'NO2', 48.15351104736328, '25.12.2011'],
#  ['Надежда', 'NO2', 37.59162521362305, '25.12.2011'],
#  ['Орлов мост', 'NO2', 45.85027694702148, '25.12.2011'],
#  ['Хиподрума', 'NO2', 51.56442642211914, '25.12.2011'],
#  ['Копитото', 'NO2', 2.419811010360718, '25.12.2011'],
#  ['Дружба', 'NO2', 33.89475250244141, '26.12.2011'],
#  ['Павлово', 'NO2', 26.36833381652832, '26.12.2011'],
#  ['Надежда', 'NO2', 20.78516387939453, '26.12.2011'],
#  ['Орлов мост', 'NO2', 26.2701587677002, '26.12.2011'],
#  ['Хиподрума', 'NO2', 28.17611312866211, '26.12.2011'],
#  ['Копитото', 'NO2', 7.266440868377686, '26.12.2011'],
#  ['Дружба', 'NO2', 32.398815155029304, '27.12.2011'],
#  ['Павлово', 'NO2', 20.28693580627441, '27.12.2011'],
#  ['Надежда', 'NO2', 16.19636726379395, '27.12.2011'],
#  ['Орлов мост', 'NO2', 22.84330558776855, '27.12.2011'],
#  ['Хиподрума', 'NO2', 18.73445892333984, '27.12.2011'],
#  ['Копитото', 'NO2', 1.5148489475250242, '27.12.2011'],
#  ['Дружба', 'NO2', 53.898170471191406, '29.12.2011'],
#  ['Павлово', 'NO2', 86.01109313964844, '29.12.2011'],
#  ['Надежда', 'NO2', 59.20818328857422, '29.12.2011'],
#  ['Орлов мост', 'NO2', 69.95642852783203, '29.12.2011'],
#  ['Хиподрума', 'NO2', 90.59327697753906, '29.12.2011'],
#  ['Копитото', 'NO2', 0.7372227907180786, '29.12.2011'],
#  ['Дружба', 'NO2', 60.059898376464844, '30.12.2011'],
#  ['Павлово', 'NO2', 85.39735412597656, '30.12.2011'],
#  ['Надежда', 'NO2', 64.08025360107422, '30.12.2011'],
#  ['Орлов мост', 'NO2', 74.99169921875, '30.12.2011'],
#  ['Хиподрума', 'NO2', 92.26634216308594, '30.12.2011'],
#  ['Копитото', 'NO2', 0.6833571195602417, '30.12.2011'],
#  ['Дружба', 'NO2', 50.81300735473633, '31.12.2011'],
#  ['Павлово', 'NO2', 40.889671325683594, '31.12.2011'],
#  ['Надежда', 'NO2', 36.3817138671875, '31.12.2011'],
#  ['Орлов мост', 'NO2', 42.73945999145508, '31.12.2011'],
#  ['Хиподрума', 'NO2', 46.48366928100586, '31.12.2011'],
#  ['Копитото', 'NO2', 3.0451650619506836, '31.12.2011'],
#  ['Дружба', 'NO2', 26.77202606201172, '01.01.2012'],
#  ['Павлово', 'NO2', 21.89352798461914, '01.01.2012'],
#  ['Надежда', 'NO2', 21.71372413635254, '01.01.2012'],
#  ['Орлов мост', 'NO2', 29.24223136901855, '01.01.2012'],
#  ['Хиподрума', 'NO2', 32.878284454345696, '01.01.2012'],
#  ['Копитото', 'NO2', 1.4706573486328118, '01.01.2012'],
#  ['Дружба', 'NO2', 46.327857971191406, '02.01.2012'],
#  ['Павлово', 'NO2', 76.733642578125, '02.01.2012'],
#  ['Надежда', 'NO2', 53.9957389831543, '02.01.2012'],
#  ['Орлов мост', 'NO2', 75.64312744140625, '02.01.2012'],
#  ['Хиподрума', 'NO2', 90.92992401123048, '02.01.2012'],
#  ['Копитото', 'NO2', 0.03326855227351189, '02.01.2012'],
#  ['Дружба', 'NO2', 98.13581085205078, '03.01.2012'],
#  ['Павлово', 'NO2', 151.7300262451172, '03.01.2012'],
#  ['Надежда', 'NO2', 96.3700942993164, '03.01.2012'],
#  ['Орлов мост', 'NO2', 118.9350433349609, '03.01.2012'],
#  ['Хиподрума', 'NO2', 166.0973510742188, '03.01.2012'],
#  ['Копитото', 'NO2', 0.05496593564748764, '03.01.2012'],
#  ['Дружба', 'NO2', 98.14828491210938, '04.01.2012'],
#  ['Павлово', 'NO2', 162.4050903320312, '04.01.2012'],
#  ['Надежда', 'NO2', 85.35342407226562, '04.01.2012'],
#  ['Орлов мост', 'NO2', 132.99238586425778, '04.01.2012'],
#  ['Хиподрума', 'NO2', 181.87420654296884, '04.01.2012'],
#  ['Копитото', 'NO2', 0.5677044987678528, '04.01.2012'],
#  ['Дружба', 'NO2', 87.83802795410156, '05.01.2012'],
#  ['Павлово', 'NO2', 111.9423675537109, '05.01.2012'],
#  ['Надежда', 'NO2', 76.07634735107422, '05.01.2012'],
#  ['Орлов мост', 'NO2', 89.46450805664062, '05.01.2012'],
#  ['Хиподрума', 'NO2', 114.5798110961914, '05.01.2012'],
#  ['Копитото', 'NO2', 2.742949247360229, '05.01.2012'],
#  ['Дружба', 'NO2', 40.19178771972656, '06.01.2012'],
#  ['Павлово', 'NO2', 42.80988693237305, '06.01.2012'],
#  ['Надежда', 'NO2', 25.9919490814209, '06.01.2012'],
#  ['Орлов мост', 'NO2', 45.95258331298828, '06.01.2012'],
#  ['Хиподрума', 'NO2', 43.25004196166992, '06.01.2012'],
#  ['Копитото', 'NO2', 3.888592958450317, '06.01.2012'],
#  ['Дружба', 'NO2', 29.18904876708984, '07.01.2012'],
#  ['Павлово', 'NO2', 12.66408061981201, '07.01.2012'],
#  ['Надежда', 'NO2', 11.01346206665039, '07.01.2012'],
#  ['Орлов мост', 'NO2', 17.91205215454102, '07.01.2012'],
#  ['Хиподрума', 'NO2', 18.55883598327637, '07.01.2012'],
#  ['Копитото', 'NO2', 1.9617592096328742, '07.01.2012'],
#  ['Дружба', 'NO2', 23.91743469238281, '08.01.2012'],
#  ['Павлово', 'NO2', 15.426631927490229, '08.01.2012'],
#  ['Надежда', 'NO2', 13.536251068115229, '08.01.2012'],
#  ['Орлов мост', 'NO2', 22.38265991210938, '08.01.2012'],
#  ['Хиподрума', 'NO2', 23.34195327758789, '08.01.2012'],
#  ['Копитото', 'NO2', 2.26362133026123, '08.01.2012'],
#  ['Дружба', 'NO2', 33.06641006469727, '09.01.2012'],
#  ['Павлово', 'NO2', 20.46732330322266, '09.01.2012'],
#  ['Надежда', 'NO2', 16.7723503112793, '09.01.2012'],
#  ['Орлов мост', 'NO2', 24.34276580810547, '09.01.2012'],
#  ['Хиподрума', 'NO2', 27.41317749023438, '09.01.2012'],
#  ['Копитото', 'NO2', 2.6327283382415767, '09.01.2012'],
#  ['Дружба', 'NO2', 33.77956390380859, '10.01.2012'],
#  ['Павлово', 'NO2', 19.70625877380371, '10.01.2012'],
#  ['Надежда', 'NO2', 17.367195129394528, '10.01.2012'],
#  ['Орлов мост', 'NO2', 22.96167945861816, '10.01.2012'],
#  ['Хиподрума', 'NO2', 24.11331367492676, '10.01.2012'],
#  ['Копитото', 'NO2', 1.9196022748947141, '10.01.2012'],
#  ['Дружба', 'NO2', 36.37479019165039, '11.01.2012'],
#  ['Павлово', 'NO2', 28.63262748718262, '11.01.2012'],
#  ['Надежда', 'NO2', 23.81746673583984, '11.01.2012'],
#  ['Орлов мост', 'NO2', 29.59382438659668, '11.01.2012'],
#  ['Хиподрума', 'NO2', 29.65389251708984, '11.01.2012'],
#  ['Копитото', 'NO2', 2.230075836181641, '11.01.2012'],
#  ['Дружба', 'NO2', 39.21582412719727, '12.01.2012'],
#  ['Павлово', 'NO2', 22.52143669128418, '12.01.2012'],
#  ['Надежда', 'NO2', 27.07834815979004, '12.01.2012'],
#  ['Орлов мост', 'NO2', 30.65249061584473, '12.01.2012'],
#  ['Хиподрума', 'NO2', 24.61418914794922, '12.01.2012'],
#  ['Копитото', 'NO2', 2.800978183746338, '12.01.2012'],
#  ['Дружба', 'NO2', 42.34748840332031, '13.01.2012'],
#  ['Павлово', 'NO2', 38.08538436889648, '13.01.2012'],
#  ['Надежда', 'NO2', 27.02489852905273, '13.01.2012'],
#  ['Орлов мост', 'NO2', 40.99265670776367, '13.01.2012'],
#  ['Хиподрума', 'NO2', 38.04113388061523, '13.01.2012'],
#  ['Копитото', 'NO2', 0.9736757874488832, '13.01.2012'],
#  ['Дружба', 'NO2', 20.95385932922363, '14.01.2012'],
#  ['Павлово', 'NO2', 9.650341987609863, '14.01.2012'],
#  ['Надежда', 'NO2', 11.74674606323242, '14.01.2012'],
#  ['Орлов мост', 'NO2', 19.07745170593262, '14.01.2012'],
#  ['Хиподрума', 'NO2', 10.23190402984619, '14.01.2012'],
#  ['Копитото', 'NO2', 1.158360123634338, '14.01.2012'],
#  ['Дружба', 'NO2', 16.67442893981934, '15.01.2012'],
#  ['Павлово', 'NO2', 9.309134483337402, '15.01.2012'],
#  ['Надежда', 'NO2', 10.37185096740723, '15.01.2012'],
#  ['Орлов мост', 'NO2', 13.013635635375982, '15.01.2012'],
#  ['Хиподрума', 'NO2', 7.255645275115968, '15.01.2012'],
#  ['Копитото', 'NO2', 1.12730884552002, '15.01.2012'],
#  ['Дружба', 'NO2', 22.86979103088379, '16.01.2012'],
#  ['Павлово', 'NO2', 14.762096405029302, '16.01.2012'],
#  ['Надежда', 'NO2', 13.31692886352539, '16.01.2012'],
#  ['Орлов мост', 'NO2', 16.65681457519531, '16.01.2012'],
#  ['Хиподрума', 'NO2', 13.324109077453608, '16.01.2012'],
#  ['Копитото', 'NO2', 1.4691834449768069, '16.01.2012'],
#  ['Дружба', 'NO2', 27.0497932434082, '17.01.2012'],
#  ['Павлово', 'NO2', 15.11631965637207, '17.01.2012'],
#  ['Надежда', 'NO2', 17.94249725341797, '17.01.2012'],
#  ['Орлов мост', 'NO2', 25.1593189239502, '17.01.2012'],
#  ['Хиподрума', 'NO2', 16.93853378295898, '17.01.2012'],
#  ['Копитото', 'NO2', 2.115824222564697, '17.01.2012'],
#  ['Дружба', 'NO2', 29.04168510437012, '18.01.2012'],
#  ['Павлово', 'NO2', 21.59693717956543, '18.01.2012'],
#  ['Надежда', 'NO2', 16.96743202209473, '18.01.2012'],
#  ['Орлов мост', 'NO2', 28.89350700378418, '18.01.2012'],
#  ['Хиподрума', 'NO2', 21.488544464111328, '18.01.2012'],
#  ['Копитото', 'NO2', 2.883414268493652, '18.01.2012'],
#  ['Дружба', 'NO2', 45.913841247558594, '19.01.2012'],
#  ['Павлово', 'NO2', 46.55694580078125, '19.01.2012'],
#  ['Надежда', 'NO2', 31.35134506225586, '19.01.2012'],
#  ['Орлов мост', 'NO2', 56.30126190185547, '19.01.2012'],
#  ['Хиподрума', 'NO2', 48.44950485229492, '19.01.2012'],
#  ['Копитото', 'NO2', 1.577883720397949, '19.01.2012'],
#  ['Дружба', 'NO2', 56.38728713989258, '20.01.2012'],
#  ['Павлово', 'NO2', 63.74139404296875, '20.01.2012'],
#  ['Надежда', 'NO2', 34.307849884033196, '20.01.2012'],
#  ['Орлов мост', 'NO2', 64.8758316040039, '20.01.2012'],
#  ['Хиподрума', 'NO2', 62.94838333129883, '20.01.2012'],
#  ['Копитото', 'NO2', 1.4099400043487549, '20.01.2012'],
#  ['Дружба', 'NO2', 28.6968994140625, '21.01.2012'],
#  ['Павлово', 'NO2', 17.06118392944336, '21.01.2012'],
#  ['Надежда', 'NO2', 14.87648487091064, '21.01.2012'],
#  ['Орлов мост', 'NO2', 19.56472778320312, '21.01.2012'],
#  ['Хиподрума', 'NO2', 16.082221984863278, '21.01.2012'],
#  ['Копитото', 'NO2', 2.2412045001983643, '21.01.2012'],
#  ['Дружба', 'NO2', 39.64170837402344, '22.01.2012'],
#  ['Павлово', 'NO2', 40.39851379394531, '22.01.2012'],
#  ['Надежда', 'NO2', 22.16074371337891, '22.01.2012'],
#  ['Орлов мост', 'NO2', 46.71093368530273, '22.01.2012'],
#  ['Хиподрума', 'NO2', 37.01054000854492, '22.01.2012'],
#  ['Копитото', 'NO2', 0.9602332711219788, '22.01.2012'],
#  ['Дружба', 'NO2', 73.9037094116211, '23.01.2012'],
#  ['Павлово', 'NO2', 108.6885528564453, '23.01.2012'],
#  ['Надежда', 'NO2', 76.51505279541016, '23.01.2012'],
#  ['Орлов мост', 'NO2', 101.4036102294922, '23.01.2012'],
#  ['Хиподрума', 'NO2', 123.55905151367192, '23.01.2012'],
#  ['Копитото', 'NO2', 0.9974570870399476, '23.01.2012'],
#  ['Дружба', 'NO2', 73.35628509521484, '24.01.2012'],
#  ['Павлово', 'NO2', 106.5546493530273, '24.01.2012'],
#  ['Надежда', 'NO2', 65.13164520263672, '24.01.2012'],
#  ...]

# %%
pd_aggregated = pd.DataFrame(data_aggregated, columns=['location', 'type', 'value', 'date'])

# %%
pd_aggregated[pd_aggregated['type'] == 'PM10'].plot.hist(['value', 'location'])

# %%
pd_aggregated[pd_aggregated['type'] == 'NO2'].describe()
# Out:
#               value
# count  10202.000000
# mean      27.509747
# std       21.054789
# min        0.010018
# 25%       13.187143
# 50%       23.505087
# 75%       36.721674
# max      181.874207

# %%
pd_aggregated[pd_aggregated['type'] == 'PM2.5'].describe()
# Out:
#              value
# count  1802.000000
# mean     30.421876
# std      43.005104
# min       0.000000
# 25%      12.006001
# 50%      18.180001
# 75%      30.447403
# max     542.693542

# %%
pd_aggregated[pd_aggregated['type'] == 'PM2.5'].head()
# Out:
#         location   type       value        date
# 21170  Хиподрума  PM2.5  523.417114  01.01.2011
# 21171  Хиподрума  PM2.5  542.693542  02.01.2011
# 21172  Хиподрума  PM2.5   46.405773  03.01.2011
# 21173  Хиподрума  PM2.5   40.991417  04.01.2011
# 21174  Хиподрума  PM2.5   22.785963  05.01.2011

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_by_location(df):
    f, ax = plt.subplots(figsize=(10, 10))
    ax.set_xscale("log")

    sb.boxplot(x="value", y="location", data=df,
                whis=np.inf)

    # Add in points to show each observation
    # sb.swarmplot(x="value", y="location", data=df,
    #               size=2, color=".3", linewidth=0)

    # Tweak the visual presentation
    ax.xaxis.grid(True)
    ax.set(ylabel="")
    sb.despine(trim=True, left=True)

# %%
df_no2 = pd_aggregated[pd_aggregated['type'] == 'NO2'][['value', 'location']]
plot_by_location(df_no2)

# %%
df_pm25 = pd_aggregated[pd_aggregated['type'] == 'PM2.5'][['value', 'location']]
plot_by_location(df_pm25)

# %%
df_pm10 = pd_aggregated[pd_aggregated['type'] == 'PM10'][['value', 'location']]
plot_by_location(df_pm10)

# %%
from datetime import date, datetime


Y = 2000 # dummy leap year to allow input X-02-29 (leap day)
seasons = [('winter', (datetime(Y,  1,  1),  datetime(Y,  3, 20))),
           ('spring', (datetime(Y,  3, 21),  datetime(Y,  6, 20))),
           ('summer', (datetime(Y,  6, 21),  datetime(Y,  9, 22))),
           ('autumn', (datetime(Y,  9, 23),  datetime(Y, 12, 20))),
           ('winter', (datetime(Y, 12, 21),  datetime(Y, 12, 31)))]

def get_season(now):
    if now == 0:
        return 'autumn'
    datetime_object = datetime.strptime(now, '%d.%m.%Y')

    datetime_object = datetime_object.replace(year=Y)
    return next(season for season, (start, end) in seasons
                if start <= datetime_object <= end)


pd_aggregated["season"] = pd_aggregated['date'].apply(get_season)

# %%
df_pm10 = pd_aggregated[(pd_aggregated['type'] == 'PM10') & (pd_aggregated['season'] == 'winter')][['value', 'location']]
plot_by_location(df_pm10)

# %%
df_pm10 = pd_aggregated[(pd_aggregated['type'] == 'PM10') & (pd_aggregated['season'] == 'summer')][['value', 'location']]
plot_by_location(df_pm10)

# %%
df_pm10 = pd_aggregated[(pd_aggregated['type'] == 'NO2') & (pd_aggregated['season'] == 'winter')][['value', 'location']]
plot_by_location(df_pm10)

# %%
df_pm10 = pd_aggregated[(pd_aggregated['type'] == 'NO2') & (pd_aggregated['season'] == 'summer')][['value', 'location']]
plot_by_location(df_pm10)
